# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/spcup-noisedataset/noise-free-sound-0162.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0177.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0161.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0336.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0034.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0261.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0223.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0014.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0354.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0141.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0249.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0520.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0080.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0526.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0216.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0079.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0517.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0495.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0363.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0314.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0599.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0501.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0450.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0044.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0068.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0087.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0287.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0103.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0254.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0100.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0573.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0466.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0197.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0184.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0076.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0143.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0227.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0304.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0611.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0207.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0467.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0333.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0016.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0180.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0504.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0025.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0484.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0454.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0115.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0117.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0356.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0272.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0084.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0006.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0455.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0135.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0001.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0320.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0431.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0359.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0045.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0317.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0351.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0497.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0316.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0549.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0266.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0245.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0169.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0176.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0198.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0294.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0542.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0060.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0049.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0056.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0414.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0464.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0041.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0496.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0324.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0072.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0506.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0557.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0190.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0373.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0128.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0366.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0350.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0142.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0311.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0099.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0423.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0404.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0062.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0508.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0303.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0078.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0260.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0365.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0121.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0571.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0400.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0158.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0007.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0371.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0580.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0075.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0152.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0486.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0221.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0335.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0576.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0005.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0498.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0536.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0424.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0420.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0386.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0533.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0328.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0239.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0178.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0026.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0444.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0575.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0065.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0159.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0421.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0228.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0215.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0374.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0150.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0195.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0614.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0475.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0129.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0329.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0468.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0155.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0545.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0179.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0376.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0263.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0415.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0194.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0578.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0164.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0140.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0462.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0493.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0258.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0205.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0349.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0339.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0394.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0558.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0338.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0269.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0153.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0167.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0474.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0507.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0297.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0004.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0277.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0595.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0597.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0478.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0442.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0511.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0070.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0015.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0413.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0410.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0337.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0183.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0157.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0122.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0291.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0280.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0380.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0399.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0417.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0612.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0055.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0064.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0262.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0563.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0582.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0321.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0133.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0247.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0531.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0581.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0568.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0448.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0529.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0273.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0081.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0583.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0510.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0163.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0530.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0225.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0021.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0212.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0543.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0357.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0175.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0505.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0514.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0547.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0440.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0592.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0114.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0609.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0382.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0226.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0199.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0232.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0300.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0148.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0594.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0436.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0202.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0146.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0298.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0208.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0069.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0295.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0033.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0200.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0524.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0090.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0253.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0610.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0429.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0457.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0325.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0057.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0305.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0375.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0369.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0396.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0348.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0490.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0086.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0479.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0342.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0170.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0379.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0515.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0132.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0248.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0389.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0487.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0173.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0085.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0077.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0246.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0310.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0541.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0031.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0252.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0427.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0104.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0499.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0509.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0127.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0051.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0229.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0485.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0112.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0489.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0083.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0327.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0323.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0503.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0238.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0309.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0606.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0230.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0054.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0318.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0009.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0201.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0019.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0052.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0326.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0189.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0463.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0097.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0139.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0111.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0181.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0042.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0156.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0430.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0059.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0477.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0050.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0435.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0522.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0593.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0213.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0538.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0607.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0188.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0018.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0437.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0165.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0235.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0554.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0383.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0598.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0209.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0418.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0422.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0186.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0397.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0360.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0074.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0602.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0035.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0591.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0037.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0528.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0432.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0345.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0138.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0192.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0023.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0251.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0233.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0313.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0284.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0020.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0022.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0204.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0109.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0331.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0256.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0168.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0434.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0096.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0154.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0488.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0502.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0381.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0367.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0555.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0108.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0473.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0307.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0491.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0319.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0471.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0268.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0438.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0590.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0393.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0091.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0094.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0408.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0358.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0237.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0124.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0290.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0282.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0032.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0218.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0552.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0286.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0274.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0106.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0368.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0566.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0120.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0134.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0047.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0456.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0572.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0008.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0330.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0452.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0110.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0000.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0210.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0361.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0306.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0058.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0267.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0476.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0276.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0296.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0567.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0043.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0387.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0270.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0082.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0451.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0605.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0278.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0459.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0105.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0098.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0346.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0039.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0519.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0562.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0392.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0217.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0416.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0048.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0224.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0066.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0384.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0439.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0145.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0588.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0027.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0028.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0113.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0405.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0378.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0540.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0559.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0550.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0144.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0092.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0458.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0412.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0426.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0449.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0093.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0250.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0428.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0244.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0029.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0283.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0521.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0395.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0586.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0446.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0214.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0482.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0584.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0352.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0377.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0275.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0370.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0299.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0013.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0388.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0535.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0281.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0553.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0166.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0003.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0131.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0312.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0587.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0046.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0196.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0441.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0071.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0332.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0616.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0472.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0036.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0613.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0500.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0445.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0480.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0615.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0017.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0372.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0271.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0265.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0403.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0220.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0585.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0364.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0149.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0402.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0211.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0231.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0589.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0544.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0172.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0095.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0053.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0391.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0565.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0460.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0518.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0222.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0525.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0406.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0171.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0160.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0574.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0012.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0119.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0362.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0494.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0411.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0390.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0556.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0539.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0512.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0570.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0024.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0219.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0010.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0264.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0118.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0401.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0470.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0461.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0242.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0465.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0130.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0601.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0063.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0236.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0483.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0344.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0257.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0355.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0241.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0002.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0579.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0125.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0407.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0191.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0353.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0136.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0527.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0409.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0147.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0577.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0596.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0600.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0564.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0447.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0123.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0604.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0608.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0398.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0569.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0532.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0206.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0088.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0322.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0255.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0433.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0174.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0341.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0107.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0182.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0061.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0187.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0285.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0340.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0513.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0193.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0419.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0151.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0334.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0292.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0203.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0548.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0481.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0302.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0534.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0560.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0523.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0101.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0343.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0546.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0126.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0243.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0137.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0293.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0561.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0516.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0308.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0240.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0073.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0453.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0492.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0288.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0279.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0038.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0067.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0603.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0443.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0425.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0259.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0116.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0289.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0385.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0301.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0537.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0347.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0234.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0030.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0315.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0011.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0102.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0185.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0089.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0469.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0551.wav
# /kaggle/input/spcup-noisedataset/noise-free-sound-0040.wav

# %%
### 1. INSTALLATIONS ###
# !pip install pyroomacoustics librosa pystoi pesq


### 2. IMPORTS ###
import pyroomacoustics as pra
import librosa
import numpy as np
import os
import glob
from scipy.signal import stft, istft
import warnings
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, ReLU, Flatten, Dense
import random
from scipy.linalg import eigh
from pesq import pesq
from pystoi import stoi
import soundfile as sf

# Suppress warnings for cleaner output
warnings.filterwarnings('ignore')
print("Libraries imported.")


### 3. DATA SETUP (MODIFIED FOR KAGGLE) ###

# Download and extract LibriSpeech (requires Internet to be ON in Kaggle)
print("Downloading LibriSpeech test-clean (OpenSLR 12)...")
# !wget -q https://www.openslr.org/resources/12/test-clean.tar.gz

print("Extracting LibriSpeech...")
# Extract to the current working directory. The '>' redirects verbose output
# !tar -xzvf test-clean.tar.gz > /dev/null
print("Download and extraction complete.")

# --- Define File Paths ---
# The data was extracted to /kaggle/working/LibriSpeech/
SPEECH_DIR = "/kaggle/working/LibriSpeech/test-clean/"

# ‼️ IMPORTANT: KAGGLE DATASET PATH FOR NOISE ‼️
# 1. Zip your local "Noise" folder.
# 2. Create a new Kaggle Dataset and upload that zip.
# 3. Add that dataset to this Kaggle notebook.
# 4. Update the path below to match your dataset name.
#
# Example: If you named your dataset 'my-noise-files' and it contains the 'Noise' folder:
# NOISE_DIR = "/kaggle/input/my-noise-files/Noise/"
#
# --- UPDATE THIS LINE ---
NOISE_DIR = "/kaggle/input/spcup-noisedataset" # <-- ‼️ UPDATE ME

# --- Find Audio Files ---
print("Locating audio files...")

# Find speech files
speech_files = glob.glob(os.path.join(SPEECH_DIR, "**", "*.flac"), recursive=True)

# Find noise files
extensions_to_check = ["*.wav", "*.mp3", "*.flac", "*.m4a"]
noise_files = []
for ext in extensions_to_check:
    noise_files.extend(glob.glob(os.path.join(NOISE_DIR, "**", ext), recursive=True))

# --- Final Check ---
if not speech_files:
    print(f"❌ ERROR: No speech files found in {SPEECH_DIR}. Check path.")
elif not noise_files:
    print(f"❌ ERROR: No noise files found in {NOISE_DIR}. Check your Kaggle dataset path.")
else:
    print(f"✅ Found {len(speech_files)} speech files.")
    print(f"✅ Found {len(noise_files)} noise files.")
    print("\nReady to proceed.")


### 4. STFT AND SIGNAL PARAMETERS ###

# --- STFT Parameters from Heymann et al. paper ---
fs_16k = 16000     # Sampling rate
N_FFT = 1024       # Frame size
HOP_LENGTH = 256
WIN_LENGTH = 1024

# --- Parameters for Data/Model Shape ---
N_BINS = (N_FFT // 2) + 1  # 513
N_MASKS = 2
WINDOW_SIZE = 11


### 5. CORE FUNCTIONS (SIMULATION, MASKING, DATA PREP) ###

def get_stft(signal):
    """Calculates the STFT of a signal."""
    _, _, Zxx = stft(signal,
                       fs=fs_16k,
                       nperseg=WIN_LENGTH,
                       noverlap=WIN_LENGTH - HOP_LENGTH,
                       nfft=N_FFT)
    return Zxx

def get_power(signal):
    """Calculates the average power of a signal."""
    return np.mean(signal**2)

def set_power(signal, ref_power):
    """Scales a signal to a desired power."""
    current_power = get_power(signal)
    if current_power == 0:
        return signal
    scale_factor = np.sqrt(ref_power / current_power)
    return signal * scale_factor

def add_wgn(signal, snr_db):
    """Adds White Gaussian Noise to a signal at a specific SNR."""
    signal_power = get_power(signal)
    noise_power = signal_power / (10**(snr_db / 10))

    # Generate noise
    wgn = np.random.normal(0, np.sqrt(noise_power), signal.shape)

    # Return the noisy signal and the noise itself
    return signal + wgn, wgn

def generate_anechoic_sample(speech_file, noise_file):
    """
    Generates one training sample for the anechoic case (Task 1).
    Returns the mixed STFT (input) and the ideal masks (target).
    """

    # === 1. Define Simulation Parameters (from SP Cup Doc) ===
    room_dim = [4.9, 4.9, 4.9]
    mic_pos_1 = [2.41, 2.45, 1.5]
    mic_pos_2 = [2.49, 2.45, 1.5]
    mic_locations = np.c_[mic_pos_1, mic_pos_2]
    speech_pos = [2.45, 3.45, 1.5]
    noise_pos = [3.22, 3.06, 1.5]

    # === 2. Load and Resample Audio ===
    try:
        speech_audio, _ = librosa.load(speech_file, sr=fs_16k, mono=True)
        noise_audio, _ = librosa.load(noise_file, sr=fs_16k, mono=True)
    except Exception as e:
        print(f"Error loading audio: {e}")
        return None, None

    # Truncate to the shorter audio length
    min_len = min(len(speech_audio), len(noise_audio))
    speech_audio = speech_audio[:min_len]
    noise_audio = noise_audio[:min_len]

    if min_len < WIN_LENGTH:
        return None, None # Skip short files

    # === 3. Run Simulation (Speech Only) ===
    room_speech = pra.ShoeBox(room_dim, fs=fs_16k, max_order=0)
    room_speech.add_microphone_array(mic_locations)
    room_speech.add_source(speech_pos, signal=speech_audio)
    room_speech.simulate()
    X_mic = room_speech.mic_array.signals.T

    # === 4. Run Simulation (Noise Only) ===
    room_noise = pra.ShoeBox(room_dim, fs=fs_16k, max_order=0)
    room_noise.add_microphone_array(mic_locations)
    room_noise.add_source(noise_pos, signal=noise_audio)
    room_noise.simulate()
    I_mic = room_noise.mic_array.signals.T

    # === 5. Truncate and Align ===
    X_mic = X_mic[:min_len, :]
    I_mic = I_mic[:min_len, :]

    # === 6. Mix Signals (0dB SIR, 5dB SNR) ===
    target_power = get_power(X_mic[:, 0])
    I_mic_scaled = set_power(I_mic, target_power)
    mixture_si = X_mic + I_mic_scaled
    mixture_final, wgn = add_wgn(mixture_si, snr_db=5.0)

    # === 7. Generate Masks (Heymann et al. method) ===
    N_total = I_mic_scaled + wgn
    X_stft = get_stft(X_mic[:, 0])
    N_stft = get_stft(N_total[:, 0])
    X_power = np.abs(X_stft)**2
    N_power = np.abs(N_stft)**2
    IBM_X = (X_power > N_power).astype(float)
    IBM_N = (N_power >= X_power).astype(float)

    # Get the STFT of the final mixed signal (for network input)
    mixture_stft_ch0 = get_stft(mixture_final[:, 0])
    mixture_stft_ch1 = get_stft(mixture_final[:, 1])

    # Stack the magnitude of the 2-channel STFTs
    network_input = np.stack([
        np.abs(mixture_stft_ch0),
        np.abs(mixture_stft_ch1)
    ], axis=-1)

    # Stack the target masks
    target_masks = np.stack([IBM_X, IBM_N], axis=-1)

    return network_input, target_masks

def create_windowed_dataset(network_input, target_masks, window_size=WINDOW_SIZE):
    """
    Converts full-length spectrograms into windowed patches
    for the CNN/FF networks.
    """
    # Pad the input so we can get a window centered on the first/last frames
    padding = window_size // 2

    # Pad the time axis (axis=0)
    input_padded = np.pad(
        network_input,
        ((padding, padding), (0, 0), (0, 0)),
        mode='reflect'
    )

    # Use a built-in Keras utility to do the sliding window
    X_patches = tf.image.extract_patches(
        images=np.expand_dims(input_padded, axis=0), # Add batch dim
        sizes=[1, window_size, N_BINS, 1],
        strides=[1, 1, 1, 1],
        rates=[1, 1, 1, 1],
        padding='VALID'
    ).numpy()

    # Squeeze and reshape
    X_patches = np.squeeze(X_patches, axis=(0, 2))
    n_frames = network_input.shape[0]
    n_channels = network_input.shape[2]
    X_patches = X_patches.reshape((n_frames, window_size, N_BINS, n_channels))

    # --- Create the target (y)
    # Reshape from (513, n_frames, 2) to (n_frames, 513, 2)
    y_swapped = np.swapaxes(target_masks, 0, 1)

    # Reshape to (n_frames, 513 * 2) -> (n_patches, 1026)
    y_masks = y_swapped.reshape((n_frames, N_BINS * N_MASKS))

    return X_patches, y_masks

def generate_data_batch(num_samples, speech_list, noise_list):
    """
    Generates a batch of (X, y) data by randomly pairing
    speech and noise files from the provided lists.
    """
    all_X_data = []
    all_y_data = []

    if not speech_list or not noise_list:
        print("❌ Error: Received empty speech_list or noise_list.")
        return None, None

    for i in range(num_samples):
        speech_file = random.choice(speech_list)
        noise_file = random.choice(noise_list)

        network_input, target_masks = generate_anechoic_sample(speech_file, noise_file)
        if network_input is None:
            continue # Skip this sample

        inp_transposed = np.transpose(network_input, (1, 0, 2))
        X_ch0, y_ch0 = create_windowed_dataset(inp_transposed[..., 0:1], target_masks)
        X_ch1, y_ch1 = create_windowed_dataset(inp_transposed[..., 1:2], target_masks)

        all_X_data.append(X_ch0)
        all_X_data.append(X_ch1)
        all_y_data.append(y_ch0)
        all_y_data.append(y_ch1)

    if not all_X_data:
        print("❌ Error: No data was generated.")
        return None, None

    X_batch = np.concatenate(all_X_data, axis=0)
    y_batch = np.concatenate(all_y_data, axis=0)

    return X_batch, y_batch

def reconstruct_masks(patched_masks, n_frames):
    """
    Converts the model's patch-based output back into
    full-length spectrogram masks.
    """
    # 1. Reshape to (n_frames, 513, 2)
    full_masks = patched_masks.reshape((n_frames, N_BINS, N_MASKS))

    # 2. Swap axes to (513, n_frames, 2)
    full_masks = np.transpose(full_masks, (1, 0, 2))

    # 3. Separate the two masks
    predicted_mask_X = full_masks[..., 0]
    predicted_mask_N = full_masks[..., 1]

    return predicted_mask_X, predicted_mask_N

def gev_beamformer(mixture_stft_2ch, mask_X, mask_N):
    """
    Applies the GEV beamformer using the predicted masks.
    """
    n_bins, n_frames, n_ch = mixture_stft_2ch.shape
    enhanced_stft = np.zeros((n_bins, n_frames), dtype=np.complex128)
    epsilon = 1e-8 # Add a small value to prevent division by zero

    # Process each frequency bin independently
    for f in range(n_bins):
        Y = mixture_stft_2ch[f, :, :].T  # Now (2, n_frames)
        m_x = mask_X[f, :]
        m_n = mask_N[f, :]

        # Calculate PSD matrices
        Phi_XX = (Y * m_x) @ Y.conj().T + epsilon * np.eye(n_ch)
        Phi_NN = (Y * m_n) @ Y.conj().T + epsilon * np.eye(n_ch)

        # Solve GEV problem
        try:
            eigenvalues, eigenvectors = eigh(Phi_XX, Phi_NN)
            filter_f = eigenvectors[:, -1] # Filter is eigenvector for largest eigenvalue
            enhanced_stft[f, :] = filter_f.conj().T @ Y
        except np.linalg.LinAlgError:
            enhanced_stft[f, :] = Y[0] # Fallback if GEV fails

    return enhanced_stft

def enhance_audio_file(model, speech_file, noise_file):
    """
    Runs the full simulation and enhancement pipeline for evaluation.
    """
    # --- 1. Simulate a Test Sample ---
    # A. Load audio
    speech_audio, _ = librosa.load(speech_file, sr=fs_16k, mono=True)
    noise_audio, _ = librosa.load(noise_file, sr=fs_16k, mono=True)
    min_len = min(len(speech_audio), len(noise_audio))
    speech_audio = speech_audio[:min_len]
    noise_audio = noise_audio[:min_len]

    # B. Set up room
    room_dim = [4.9, 4.9, 4.9]
    mic_locations = np.c_[[2.41, 2.45, 1.5], [2.49, 2.45, 1.5]]
    speech_pos = [2.45, 3.45, 1.5]
    noise_pos = [3.22, 3.06, 1.5]

    # C. Simulate Speech
    room_speech = pra.ShoeBox(room_dim, fs=fs_16k, max_order=0)
    room_speech.add_microphone_array(mic_locations)
    room_speech.add_source(speech_pos, signal=speech_audio)
    room_speech.simulate()
    X_mic = room_speech.mic_array.signals.T[:min_len, :]

    # D. Simulate Noise
    room_noise = pra.ShoeBox(room_dim, fs=fs_16k, max_order=0)
    room_noise.add_microphone_array(mic_locations)
    room_noise.add_source(noise_pos, signal=noise_audio)
    room_noise.simulate()
    I_mic = room_noise.mic_array.signals.T[:min_len, :]

    # E. Mix signals
    target_power = get_power(X_mic[:, 0])
    I_mic_scaled = set_power(I_mic, target_power)
    mixture_si = X_mic + I_mic_scaled
    mixture_final, wgn = add_wgn(mixture_si, snr_db=5.0)

    # --- 2. Get STFTs ---
    mixture_stft_ch0 = get_stft(mixture_final[:, 0])
    mixture_stft_ch1 = get_stft(mixture_final[:, 1])
    mixture_stft_2ch = np.stack([mixture_stft_ch0, mixture_stft_ch1], axis=-1)
    network_input = np.stack([np.abs(mixture_stft_ch0), np.abs(mixture_stft_ch1)], axis=-1)
    n_frames = network_input.shape[1]

    # --- 3. Prepare Patches for CNN ---
    inp_transposed = np.transpose(network_input, (1, 0, 2))
    # Create dummy masks (not used)
    dummy_masks = np.zeros((N_BINS, n_frames, N_MASKS)) 
    X_ch0, _ = create_windowed_dataset(inp_transposed[..., 0:1], dummy_masks)
    X_ch1, _ = create_windowed_dataset(inp_transposed[..., 1:2], dummy_masks)

    # --- 4. Predict Masks ---
    pred_masks_ch0 = model.predict(X_ch0, verbose=0)
    pred_masks_ch1 = model.predict(X_ch1, verbose=0)
    avg_patched_masks = (pred_masks_ch0 + pred_masks_ch1) / 2.0

    # --- 5. Reconstruct Masks ---
    pred_mask_X, pred_mask_N = reconstruct_masks(avg_patched_masks, n_frames)

    # --- 6. Apply GEV Beamformer ---
    enhanced_stft = gev_beamformer(mixture_stft_2ch, pred_mask_X, pred_mask_N)

    # --- 7. Reconstruct Audio ---
    _, enhanced_audio = istft(
        enhanced_stft,
        fs=fs_16k,
        nperseg=WIN_LENGTH,
        noverlap=WIN_LENGTH - HOP_LENGTH,
        nfft=N_FFT
    )
    
    clean_speech_audio = X_mic[:, 0]
    min_len_out = min(len(enhanced_audio), len(clean_speech_audio))
    
    return enhanced_audio[:min_len_out], clean_speech_audio[:min_len_out]

def calculate_snr(signal, noise):
    """Calculates the Signal-to-Noise Ratio (SNR) in decibels (dB)."""
    signal_power = np.mean(signal**2)
    noise_power = np.mean(noise**2)
    if noise_power == 0:
        return float('inf')
    snr_db = 10 * np.log10(signal_power / noise_power)
    return snr_db


### 6. MODEL DEFINITION ###

def build_cnn_model(input_shape=(WINDOW_SIZE, N_BINS, 1)):
    """
    Builds a Keras CNN model based on the intent of the Heymann et al. paper.
    Input shape is (frames, freqs, 1)
    """
    inputs = Input(shape=input_shape)
    # --- Conv Block 1 ---
    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(inputs)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    # --- Conv Block 2 ---
    x = Conv2D(filters=32, kernel_size=(3, 3), padding='same')(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    # --- Flatten & Dense ---
    x = Flatten()(x)
    x = Dense(513)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)
    # --- Output Layer ---
    # Output is 1026 (513 bins * 2 masks)
    outputs = Dense(N_BINS * N_MASKS, activation='sigmoid')(x) 
    
    model = Model(inputs=inputs, outputs=outputs)
    model.compile(optimizer='adam', loss='binary_crossentropy')
    return model


### 7. MAIN EXECUTION SCRIPT ###

# Check if data files were found before proceeding
if speech_files and noise_files:

    # --- 7a. Define Model ---
    print("\n--- Building Model ---")
    cnn_model = build_cnn_model(input_shape=(WINDOW_SIZE, N_BINS, 1))
    cnn_model.summary()

    # --- 7b. Generate Fixed Validation Set ---
    VAL_SAMPLES_FIXED = 50 # Reduced from 100 for speed in Kaggle
    print(f"\n--- Generating FIXED validation set with {VAL_SAMPLES_FIXED} samples... ---")
    
    X_val_fixed, y_val_fixed = generate_data_batch(
        VAL_SAMPLES_FIXED, speech_files, noise_files
    )

    if X_val_fixed is not None:
        print(f"✅ Fixed validation set created.")
        print(f"   X_val_fixed shape: {X_val_fixed.shape}")
        print(f"   y_val_fixed shape: {y_val_fixed.shape}")

        # --- 7c. Generate Static Training Set ---
        N_TRAINING_SAMPLES = 200 # Reduced from 500 for speed in Kaggle
        print(f"\n--- Generating STATIC training set with {N_TRAINING_SAMPLES} samples... ---")
        
        X_train_static, y_train_static = generate_data_batch(
            N_TRAINING_SAMPLES, speech_files, noise_files
        )

        if X_train_static is not None:
            print(f"\n✅ Static Training Set created.")
            print(f"   X_train_static shape: {X_train_static.shape}")
            print(f"   y_train_static shape: {y_train_static.shape}")

            # --- 7d. Train the Model ---
            EPOCHS = 30
            BATCH_SIZE = 32
            print(f"\n--- Starting training for {EPOCHS} epochs... ---")
            
            history = cnn_model.fit(
                X_train_static,
                y_train_static,
                epochs=EPOCHS,
                batch_size=BATCH_SIZE,
                validation_data=(X_val_fixed, y_val_fixed),
                shuffle=True
            )
            print("\n✅✅✅ Static Training complete! ✅✅✅")

            # --- 7e. Evaluate the Model ---
            print("\n--- Running Final Evaluation ---")
            test_speech_file = random.choice(speech_files)
            test_noise_file = random.choice(noise_files)

            print("Running full pipeline on new test files:")
            print(f"   Speech: {os.path.basename(test_speech_file)}")
            print(f"   Noise:  {os.path.basename(test_noise_file)}")

            enhanced_audio, clean_audio = enhance_audio_file(
                cnn_model,
                test_speech_file,
                test_noise_file
            )

            print("\n--- Evaluation Metrics ---")
            stoi_score = stoi(clean_audio, enhanced_audio, fs_16k)
            print(f"STOI Score: {stoi_score:.4f} (Higher is better, 0 to 1)")
            
            pesq_score = pesq(fs_16k, clean_audio, enhanced_audio, 'nb')
            print(f"PESQ Score: {pesq_score:.4f} (Higher is better, -0.5 to 4.5)")

            # Save files to /kaggle/working/
            sf.write("enhanced_output.wav", enhanced_audio, fs_16k)
            sf.write("original_clean.wav", clean_audio, fs_16k)
            print("\nSaved 'enhanced_output.wav' and 'original_clean.wav' to /kaggle/working/")

        else:
            print("❌ Error creating training set. Skipping training.")
    else:
        print("❌ Error creating validation set. Skipping training.")

    # --- 7f. SNR Function Example ---
    print("\n--- SNR Calculation Example ---")
    t = np.linspace(0, 1, 1000)
    signal = np.sin(2 * np.pi * 5 * t)
    noise = np.random.normal(0, 0.5, 1000)
    snr_value = calculate_snr(signal, noise)
    print(f"Signal Power: {np.mean(signal**2):.4f}")
    print(f"Noise Power:  {np.mean(noise**2):.4f}")
    print(f"SNR: {snr_value:.2f} dB")

else:
    print("\n‼️ Skipping script execution because data files were not found.")
    print("Please check your SPEECH_DIR and NOISE_DIR paths.")
# Out:
# Collecting pyroomacoustics
#   Downloading pyroomacoustics-0.8.6.tar.gz (35.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.1/35.1 MB 51.3 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.11.0)
# Collecting pystoi
#   Downloading pystoi-0.4.1-py2.py3-none-any.whl.metadata (4.0 kB)
# Collecting pesq
#   Downloading pesq-0.0.4.tar.gz (38 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython in /usr/local/lib/python3.11/dist-packages (from pyroomacoustics) (3.0.12)
# Requirement already satisfied: numpy>=1.13.0 in /usr/local/lib/python3.11/dist-packages (from pyroomacoustics) (1.26.4)
# Requirement already satisfied: scipy>=0.18.0 in /usr/local/lib/python3.11/dist-packages (from pyroomacoustics) (1.15.3)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.11/dist-packages (from pyroomacoustics) (3.0.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.2.2)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.1)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing_extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.15.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy_loader>=0.1->librosa) (25.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.13.0->pyroomacoustics) (2.4.1)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.4.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.5)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.1.0->librosa) (3.6.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.23)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.8.3)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.13.0->pyroomacoustics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.13.0->pyroomacoustics) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.13.0->pyroomacoustics) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.13.0->pyroomacoustics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.13.0->pyroomacoustics) (2024.2.0)
# Downloading pystoi-0.4.1-py2.py3-none-any.whl (8.2 kB)
# Building wheels for collected packages: pyroomacoustics, pesq
#   Building wheel for pyroomacoustics (pyproject.toml) ... done
#   Created wheel for pyroomacoustics: filename=pyroomacoustics-0.8.6-cp311-cp311-linux_x86_64.whl size=46975507 sha256=195ef2e10cedbbabcc50cc092a6256e92af25edb8d92ee18751a5e222fbf0e2a
#   Stored in directory: /root/.cache/pip/wheels/b5/bf/fd/9341e725ad76d9c7acafc76d6fccb0ff597699ef37eee33f8c
#   Building wheel for pesq (setup.py) ... done
#   Created wheel for pesq: filename=pesq-0.0.4-cp311-cp311-linux_x86_64.whl size=275948 sha256=699656150952b90b38d6b544b83d080e6538b6de7d3a17ebad0e5e3a798bd939
#   Stored in directory: /root/.cache/pip/wheels/ae/f1/23/2698d0bf31eec2b2aa50623b5d93b6206c49c7155d0e31345d
# Successfully built pyroomacoustics pesq
# Installing collected packages: pesq, pystoi, pyroomacoustics
# Successfully installed pesq-0.0.4 pyroomacoustics-0.8.6 pystoi-0.4.1
# 2025-11-06 17:48:23.745917: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1762451304.169288      37 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1762451304.338619      37 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Libraries imported.
# Downloading LibriSpeech test-clean (OpenSLR 12)...
# Extracting LibriSpeech...
# Download and extraction complete.
# Locating audio files...
# ✅ Found 2620 speech files.
# ✅ Found 617 noise files.
#
# Ready to proceed.
#
# --- Building Model ---
# I0000 00:00:1762451345.769394      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13942 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1762451345.770090      37 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13942 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 11, 513, 1)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 11, 513, 32)    │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 11, 513, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu (ReLU)                    │ (None, 11, 513, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 11, 513, 32)    │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 11, 513, 32)    │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_1 (ReLU)                  │ (None, 11, 513, 32)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 180576)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 513)            │    92,636,001 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 513)            │         2,052 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ re_lu_2 (ReLU)                  │ (None, 513)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1026)           │       527,364 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,175,241 (355.44 MB)
#  Trainable params: 93,174,087 (355.43 MB)
#  Non-trainable params: 1,154 (4.51 KB)
# --- Generating FIXED validation set with 50 samples... ---
# ✅ Fixed validation set created.
#    X_val_fixed shape: (38238, 11, 513, 1)
#    y_val_fixed shape: (38238, 1026)
#
# --- Generating STATIC training set with 200 samples... ---
#
# ✅ Static Training Set created.
#    X_train_static shape: (132776, 11, 513, 1)
#    y_train_static shape: (132776, 1026)
#
# --- Starting training for 30 epochs... ---
# Epoch 1/30
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1762451406.573055     168 service.cc:148] XLA service 0x7c3f1000f8d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1762451406.575858     168 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762451406.575880     168 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1762451407.139876     168 cuda_dnn.cc:529] Loaded cuDNN version 90300
#    5/4150 ━━━━━━━━━━━━━━━━━━━━ 2:09 31ms/step - loss: 0.6606
# I0000 00:00:1762451411.421027     168 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 151s 34ms/step - loss: 0.1804 - val_loss: 0.6033
# Epoch 2/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.1306 - val_loss: 1.3110
# Epoch 3/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.1123 - val_loss: 0.8449
# Epoch 4/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.0965 - val_loss: 3.4788
# Epoch 5/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.0822 - val_loss: 3.3339
# Epoch 6/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.0695 - val_loss: 0.3362
# Epoch 7/30
# 4150/4150 ━━━━━━━━━━━━━━━━━━━━ 138s 33ms/step - loss: 0.0595 - val_loss: 6.9587
# Epoch 8/30
# 4003/4150 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - loss: 0.0516
